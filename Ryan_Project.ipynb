# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaif95/AICamp_DS/blob/main/Ryan_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

stock = 'AAPL'

# URL of the raw CSV file on GitHub
csv_url = 'https://raw.githubusercontent.com/yumoxu/stocknet-dataset/master/price/raw/'+ stock +'.csv'

# Read the CSV data into a pandas DataFrame
df = pd.read_csv(csv_url)
df.index.name = 'Date '
df.shape

# Display the DataFrame
print(df.head(3))
print(df.tail(3))
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# Date
# 0      2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140
# 1      2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338
# 2      2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956
#
#          Volume
# Date
# 0      91973000
# 1      84093800
# 2      97799100
#              Date        Open        High         Low       Close   Adj Close  \
# Date
# 1255   2017-08-30  163.800003  163.889999  162.610001  163.350006  163.350006
# 1256   2017-08-31  163.639999  164.520004  163.479996  164.000000  164.000000
# 1257   2017-09-01  164.800003  164.940002  163.630005  164.050003  164.050003
#
#          Volume
# Date
# 1255   27269600
# 1256   26785100
# 1257   16552800

# %%
pip install --upgrade mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
df[["Year", "Month", "Day"]] = df['Date'].str.split("-", expand = True)
df.head()

# def plot_line(years):
  # mpf.plot(df.tail(), type='line')

# years = input("How many years of data would you like to see: ")
# plot_line(int(years))
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# Date
# 0      2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140
# 1      2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338
# 2      2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956
# 3      2012-09-07  96.864288  97.497147  96.538574  97.205711  87.827171
# 4      2012-09-10  97.207146  97.612854  94.585716  94.677139  85.542564
#
#           Volume  Year Month Day
# Date
# 0       91973000  2012    09  04
# 1       84093800  2012    09  05
# 2       97799100  2012    09  06
# 3       82416600  2012    09  07
# 4      121999500  2012    09  10
